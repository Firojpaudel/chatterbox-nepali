# %% [markdown]
# # 🇳🇵 Chatterbox Nepali TTS — Colab Inference
#
# [![Open In Colab](https://colab.research.google.com/assets/colab-badge.svg)](https://colab.research.google.com/github/Firojpaudel/chatterbox-nepali/blob/master/Chatterbox_Nepali_Colab.ipynb)
#
# This notebook allows you to run the **WiseYak Nepali TTS** interface using free cloud GPUs.
#
# ### 🚀 Features in this Fork:
# - **Nepali & English Support**: Language-aware text sanitization.
# - **Stability Fixes**: No more CUDA `device-side assert` crashes.
# - **Hallucination Protection**: Optional analyzer to prevent infinite loops.
# - **Checkpoint Switching**: Easily switch between base and fine-tuned models.
#
# ### 🛠️ Setup Instructions:
# 1. Go to **Runtime > Change runtime type** and ensure **T4 GPU** is selected.
# 2. Run the cells below.

# %%
# @title 🛠️ Step 1: Install Dependencies
# !git clone https://github.com/Firojpaudel/chatterbox-nepali.git
# %cd chatterbox-nepali

# Install core chatterbox and dependencies
# !pip install -e .
# !pip install perth safetensors huggingface_hub diffusers torchaudio

# Final check for missing libs commonly needed
# !pip install pykakasi russian-text-stresser g2p-en

# %%
# @title 🚀 Step 2: Launch Gradio App
# This will generate a public URL (gradio.live) at the bottom
# !python gradio_app.py

# %% [markdown]
# ### 💡 Usage Tips:
# - **Base Model**: If the output sounds robotic or repeating, try unchecking **"Hallucination Protection"** in the UI.
# - **English Punctuation**: The sanitizer now preserves apostrophes and hyphens for better English quality.
# - **Logs**: Check the terminal output at the bottom of the launch cell to see which checkpoint is currently active.
